# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandacisneross/unidad3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# actividasd 2 conceptos basicos de matplotlib 4 de noviembre del 2025
# fernanda cisneros
# ---------------------------
# conceptos basicos de la libreria matplotlib
# matplotlib es una libreria de trasados graficos de bajo nivel en python que sirve como una herramienta de visualizacion.matplotlib es de codigo abierto y podemos utilizarlo libremente.matplotlib esta escrito principalmente en python con algunos segmentos escritos en C.
# instalacion de matplotlib
# si tienes python y pip ya instalado en tu sistema,instala matplotlib utilizando el siguiente comando:

# %%
pip install matplotlib

# %% [markdown]
# desde la linea de comando.
# importar matplotlib
# una vez instalado matplotlib,importalo en tus aplicaciones agregando el modulo import,
# ejemplo:

# %%
import matplotlib

# %% [markdown]
# matplotlib pyplot
#
# pyplot
# la mayoria de las herramientas de matplotlib se encuentran dentro del submodulo pyplot y normalmente se importan bajo el alias plt

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ahora el paquete pyplot puede denominarse plt.
